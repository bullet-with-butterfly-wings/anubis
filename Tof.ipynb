# %%
from tools import Correction_tools as Ctools
from tools import Reconstruction_tools as Rtools
from tools import Overview_tools as Otools
import importlib
import pickle
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd

# %%
importlib.reload(Ctools)
importlib.reload(Rtools)
importlib.reload(Otools)
import matplotlib.pyplot as plt

file_name = "example_chunks"
storage_name = f"data/{file_name}.pkl"
with open(storage_name, "rb") as inp:
    total_chunks = pickle.load(inp)
   
chunks = total_chunks
print("Chunks Loaded")
# Out:
# Chunks Loaded

# %%
importlib.reload(Ctools)
tof = Ctools.TOF_analyser()
times = tof.collect_tof(chunks[:350])
tof.plot_tof()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       2 tof = Ctools.TOF_analyser()
#       3 times = tof.collect_tof(chunks[:300])
# ----> 4 tof.plot_tof()
#
# File ~/Coding/anubis/tools/Correction_tools.py:274, in TOF_analyser.plot_tof(self)
#     272 hist, bins = np.histogram(data, bins=np.arange(0, 20, 0.8), range=(0, 20))
#     273 bins = bins[:-1]
# --> 274 popt, pcov = curve_fit(gaus, bins, hist, p0=[1, 13, 5])
#     275 fitX = np.linspace(min(bins), max(bins), 400)
#     276 yrange = ax.get_ylim()
#
# File ~/Coding/anubis/venv/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1012, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1010     cost = np.sum(infodict['fvec'] ** 2)
#    1011     if ier not in [1, 2, 3, 4]:
# ...
